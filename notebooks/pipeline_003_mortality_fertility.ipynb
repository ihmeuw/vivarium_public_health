# %% [markdown]
# # Pipeline example, mortality and mortality

# %%
import datetime
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import time

from vivarium import InteractiveContext
from vivarium.framework.configuration import build_simulation_configuration
from vivarium.config_tree import ConfigTree

from vivarium_public_health.population import FertilityAgeSpecificRates
from vivarium_public_health.population import Mortality

from vivarium_public_health.population.spenser_population import TestPopulation
from vivarium_public_health.population.spenser_population import build_mortality_table
from vivarium_public_health.population.spenser_population import transform_rate_table
from vivarium_public_health.population.spenser_population import prepare_dataset

from vivarium_public_health.utilities import read_config_file

# %% [markdown]
# ## Base plugins for simulation

# %%
def base_plugins_simulation():
    config = {'required': {
                  'data': {
                      'controller': 'vivarium_public_health.testing.mock_artifact.MockArtifactManager',
                      'builder_interface': 'vivarium.framework.artifact.ArtifactInterface'
                  }
             }
    }

    return ConfigTree(config)

# %% [markdown]
# ## Configure a simulation

# %%
def config_simulation(inp_file):
    
    if inp_file['prepare_data']['prepare']:
        # read a dataset (normally from daedalus), change columns to be readable by vivarium
        # this function creates a file saved at output_path
        prepare_dataset(
            dataset_path=inp_file['prepare_data']['path_to_dataset'], 
            output_path=inp_file['prepare_data']['path_to_output'],
            lookup_ethnicity=inp_file['prepare_data']['path_to_lookup_ethnicity'],
            columns_map=inp_file['prepare_data']['columns_map'],
            location_code=inp_file['prepare_data']['location_code']
        )
    
    # ============= CONFIGURATION
    if inp_file['configuration']['population']['population_size'] <= 0:
        pop_size = len(pd.read_csv(inp_file['paths']['path_to_pop_file']))
    else:
        pop_size = inp_file['configuration']['population']['population_size']
    
    # config object
    config = build_simulation_configuration()
    config.update({
        'time': {
            'start': inp_file['configuration']['time']['start'],
            'end': inp_file['configuration']['time']['end'],
            'step_size': inp_file['configuration']['time']['step_size']
        },
        'randomness': inp_file['configuration']['randomness'],
        'input_data': inp_file['configuration']['input_data'],
    }, 
        layer='model_override')
    
    config.update({
        'path_to_pop_file': inp_file['paths']['path_to_pop_file'],
        'path_to_mortality_file': inp_file['paths']['path_to_mortality_file'],
        'path_to_fertility_file': inp_file['paths']['path_to_fertility_file'],
        
        'population': {
            'population_size': pop_size,
            'age_start': inp_file['configuration']['population']['age_start'],
            'age_end': inp_file['configuration']['population']['age_end'],
        },
        },
    )
    return config

# %% [markdown]
# ## Create an interactive context manager

# %%
inp_file = read_config_file("../config/model_specification.yaml")

base_plugins = base_plugins_simulation()
config = config_simulation(inp_file=inp_file)
components = [eval(x) for x in inp_file["list_components"]]
simulation = InteractiveContext(components=components,
                                configuration=config,
                                plugin_configuration=base_plugins,
                                setup=False)
# Out:
# WARNING: BLO ethnicity is removed from the dataset
#
# Write the dataset at: ../persistant_data/test_ssm_E08000032_MSOA11_ppp_2011.csv

# %% [markdown]
# ## Mortality rates

# %%
df = pd.read_csv(config.path_to_mortality_file)
# to save time, only look at locatiosn existing on the test dataset.
mortality_rate_df = df[(df['LAD.code']=='E08000032')]

asfr_data = transform_rate_table(mortality_rate_df,
                                      2011,
                                      2012,
                                      config.population.age_start,
                                      config.population.age_end)

simulation._data.write("cause.all_causes.cause_specific_mortality_rate", asfr_data)

# %% [markdown]
# ## Fertility rates

# %%
df = pd.read_csv(config.path_to_fertility_file)
# to save time, only look at locatiosn existing on the test dataset.
fertility_rate_df = df[(df['LAD.code']=='E08000032')]

asfr_data_fertility = transform_rate_table(fertility_rate_df,
                                      2011,
                                      2012,
                                      10,  # starting age for fertility
                                      50,  # finishing age for fertility
                                      [2]) # gender (only females [2])


simulation._data.write("covariate.age_specific_fertility_rate.estimate", asfr_data_fertility)

# %%
fertility_rate_df
# Out:
#       LAD.name   LAD.code ETH.group    F10.11    F11.12    F12.13    F13.14  \
# 63    Bradford  E08000032       WBI  0.000024  0.000222  0.001491  0.003435
# 452   Bradford  E08000032       WHO  0.000027  0.000250  0.001677  0.003861
# 841   Bradford  E08000032       MIX  0.000001  0.000021  0.000279  0.000829
# 1230  Bradford  E08000032       IND  0.000012  0.000145  0.001222  0.003062
# 1619  Bradford  E08000032       PAK  0.001203  0.004640  0.015877  0.027779
# 2008  Bradford  E08000032       BAN  0.001304  0.005031  0.017212  0.030114
# 2397  Bradford  E08000032       CHI  0.000001  0.000018  0.000236  0.000700
# 2786  Bradford  E08000032       OAS  0.000002  0.000030  0.000391  0.001161
# 3175  Bradford  E08000032       BLA  0.000515  0.002318  0.008990  0.016586
# 3564  Bradford  E08000032       BLC  0.000341  0.001536  0.005955  0.010986
# 3953  Bradford  E08000032       OBL  0.000001  0.000018  0.000231  0.000685
# 4342  Bradford  E08000032       OTH  0.000001  0.000026  0.000331  0.000984
#
#         F14.15    F15.16    F16.17  ...  F91.92  F92.93  F93.94  F94.95  \
# 63    0.006925  0.012484  0.020466  ...       0       0       0       0
# 452   0.007784  0.014034  0.023007  ...       0       0       0       0
# 841   0.002076  0.004508  0.008678  ...       0       0       0       0
# 1230  0.006628  0.012687  0.021878  ...       0       0       0       0
# 1619  0.044059  0.064340  0.087610  ...       0       0       0       0
# 2008  0.047762  0.069749  0.094974  ...       0       0       0       0
# 2397  0.001751  0.003802  0.007319  ...       0       0       0       0
# 2786  0.002907  0.006310  0.012147  ...       0       0       0       0
# 3175  0.027571  0.041979  0.059329  ...       0       0       0       0
# 3564  0.018262  0.027806  0.039298  ...       0       0       0       0
# 3953  0.001715  0.003724  0.007167  ...       0       0       0       0
# 4342  0.002464  0.005350  0.010298  ...       0       0       0       0
#
#       F95.96  F96.97  F97.98  F98.99  F99.100  F100.101p
# 63         0       0       0       0        0          0
# 452        0       0       0       0        0          0
# 841        0       0       0       0        0          0
# 1230       0       0       0       0        0          0
# 1619       0       0       0       0        0          0
# 2008       0       0       0       0        0          0
# 2397       0       0       0       0        0          0
# 2786       0       0       0       0        0          0
# 3175       0       0       0       0        0          0
# 3564       0       0       0       0        0          0
# 3953       0       0       0       0        0          0
# 4342       0       0       0       0        0          0
#
# [12 rows x 208 columns]

# %% [markdown]
# ## Setup a simulation and run for `num_days`

# %%
sim_start = time.time()

simulation.setup()
num_days = 365*1 + 10
simulation.run_for(duration=pd.Timedelta(days=num_days))

sim_end = time.time()
# Out:
# 2020-07-07 14:35:42.887 | DEBUG    | vivarium.framework.values:register_value_modifier:373 - Registering metrics.1.population_manager.metrics as modifier to metrics
# 2020-07-07 14:35:43.706 | DEBUG    | vivarium.framework.values:_register_value_producer:323 - Registering value pipeline fertility rate
# 2020-07-07 14:35:47.066 | DEBUG    | vivarium.framework.values:_register_value_producer:323 - Registering value pipeline mortality_rate
# 2020-07-07 14:35:47.067 | DEBUG    | vivarium.framework.values:_register_value_producer:323 - Registering value pipeline metrics
# VBox(children=(HTML(value=''), IntProgress(value=0, max=375)))
# 2020-07-07 14:36:35.287 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-01 00:00:00
# 2020-07-07 14:36:48.244 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-02 00:00:00
# 2020-07-07 14:37:02.384 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-03 00:00:00
# 2020-07-07 14:37:16.070 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-04 00:00:00
# 2020-07-07 14:37:37.433 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-05 00:00:00
# 2020-07-07 14:37:51.152 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-06 00:00:00
# 2020-07-07 14:38:02.206 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-07 00:00:00
# 2020-07-07 14:38:20.347 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-08 00:00:00
# 2020-07-07 14:38:38.851 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-09 00:00:00
# 2020-07-07 14:38:53.371 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-10 00:00:00
# 2020-07-07 14:39:07.992 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-11 00:00:00
# 2020-07-07 14:39:22.484 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-12 00:00:00
# 2020-07-07 14:39:37.036 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-13 00:00:00
# 2020-07-07 14:39:51.744 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-14 00:00:00
# 2020-07-07 14:40:02.601 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-15 00:00:00
# 2020-07-07 14:40:13.378 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-16 00:00:00
# 2020-07-07 14:40:27.787 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-17 00:00:00
# 2020-07-07 14:40:42.351 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-18 00:00:00
# 2020-07-07 14:40:56.645 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-19 00:00:00
# 2020-07-07 14:41:14.758 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-20 00:00:00
# 2020-07-07 14:41:39.825 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-21 00:00:00
# 2020-07-07 14:41:57.972 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-22 00:00:00
# 2020-07-07 14:42:08.860 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-23 00:00:00
# 2020-07-07 14:42:30.975 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-24 00:00:00
# 2020-07-07 14:42:49.138 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-25 00:00:00
# 2020-07-07 14:43:03.812 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-26 00:00:00
# 2020-07-07 14:43:22.102 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-27 00:00:00
# 2020-07-07 14:43:36.654 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-28 00:00:00
# 2020-07-07 14:43:51.141 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-29 00:00:00
# 2020-07-07 14:44:05.651 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-30 00:00:00
# 2020-07-07 14:44:30.740 | DEBUG    | vivarium.framework.engine:step:140 - 2011-01-31 00:00:00
# 2020-07-07 14:44:45.211 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-01 00:00:00
# 2020-07-07 14:44:56.224 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-02 00:00:00
# 2020-07-07 14:45:07.218 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-03 00:00:00
# 2020-07-07 14:45:25.353 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-04 00:00:00
# 2020-07-07 14:45:39.889 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-05 00:00:00
# 2020-07-07 14:45:54.379 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-06 00:00:00
# 2020-07-07 14:46:12.446 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-07 00:00:00
# 2020-07-07 14:46:23.343 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-08 00:00:00
# 2020-07-07 14:46:41.555 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-09 00:00:00
# 2020-07-07 14:46:56.134 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-10 00:00:00
# 2020-07-07 14:47:14.314 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-11 00:00:00
# 2020-07-07 14:47:25.241 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-12 00:00:00
# 2020-07-07 14:47:43.512 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-13 00:00:00
# 2020-07-07 14:47:54.224 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-14 00:00:00
# 2020-07-07 14:48:08.876 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-15 00:00:00
# 2020-07-07 14:48:19.641 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-16 00:00:00
# 2020-07-07 14:48:33.030 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-17 00:00:00
# 2020-07-07 14:48:47.571 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-18 00:00:00
# 2020-07-07 14:49:06.177 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-19 00:00:00
# 2020-07-07 14:49:28.935 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-20 00:00:00
# 2020-07-07 14:49:47.840 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-21 00:00:00
# 2020-07-07 14:49:59.361 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-22 00:00:00
# 2020-07-07 14:50:14.450 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-23 00:00:00
# 2020-07-07 14:50:29.465 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-24 00:00:00
# 2020-07-07 14:50:44.533 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-25 00:00:00
# 2020-07-07 14:50:59.075 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-26 00:00:00
# 2020-07-07 14:51:10.028 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-27 00:00:00
# 2020-07-07 14:51:24.626 | DEBUG    | vivarium.framework.engine:step:140 - 2011-02-28 00:00:00
# 2020-07-07 14:51:39.317 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-01 00:00:00
# 2020-07-07 14:51:53.835 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-02 00:00:00
# 2020-07-07 14:52:08.762 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-03 00:00:00
# 2020-07-07 14:52:23.424 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-04 00:00:00
# 2020-07-07 14:52:52.548 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-05 00:00:00
# 2020-07-07 14:53:07.144 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-06 00:00:00
# 2020-07-07 14:53:21.861 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-07 00:00:00
# 2020-07-07 14:53:29.234 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-08 00:00:00
# 2020-07-07 14:53:43.784 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-09 00:00:00
# 2020-07-07 14:53:58.309 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-10 00:00:00
# 2020-07-07 14:54:16.163 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-11 00:00:00
# 2020-07-07 14:54:30.265 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-12 00:00:00
# 2020-07-07 14:54:41.266 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-13 00:00:00
# 2020-07-07 14:54:55.212 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-14 00:00:00
# 2020-07-07 14:55:08.251 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-15 00:00:00
# 2020-07-07 14:55:24.659 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-16 00:00:00
# 2020-07-07 14:55:37.721 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-17 00:00:00
# 2020-07-07 14:55:53.946 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-18 00:00:00
# 2020-07-07 14:56:03.764 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-19 00:00:00
# 2020-07-07 14:56:13.562 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-20 00:00:00
# 2020-07-07 14:56:33.269 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-21 00:00:00
# 2020-07-07 14:56:49.555 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-22 00:00:00
# 2020-07-07 14:56:59.259 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-23 00:00:00
# 2020-07-07 14:57:15.550 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-24 00:00:00
# 2020-07-07 14:57:35.234 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-25 00:00:00
# 2020-07-07 14:57:48.367 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-26 00:00:00
# 2020-07-07 14:58:05.733 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-27 00:00:00
# 2020-07-07 14:58:16.153 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-28 00:00:00
# 2020-07-07 14:58:25.704 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-29 00:00:00
# 2020-07-07 14:58:42.037 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-30 00:00:00
# 2020-07-07 14:58:54.800 | DEBUG    | vivarium.framework.engine:step:140 - 2011-03-31 00:00:00
# 2020-07-07 14:59:07.691 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-01 00:00:00
# 2020-07-07 14:59:17.549 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-02 00:00:00
# 2020-07-07 14:59:27.025 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-03 00:00:00
# 2020-07-07 14:59:41.262 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-04 00:00:00
# 2020-07-07 14:59:54.536 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-05 00:00:00
# 2020-07-07 15:00:07.658 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-06 00:00:00
# 2020-07-07 15:00:17.295 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-07 00:00:00
# 2020-07-07 15:00:33.886 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-08 00:00:00
# 2020-07-07 15:00:47.104 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-09 00:00:00
# 2020-07-07 15:01:06.761 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-10 00:00:00
# 2020-07-07 15:01:16.353 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-11 00:00:00
# 2020-07-07 15:01:32.829 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-12 00:00:00
# 2020-07-07 15:01:45.710 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-13 00:00:00
# 2020-07-07 15:02:02.218 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-14 00:00:00
# 2020-07-07 15:02:18.408 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-15 00:00:00
# 2020-07-07 15:02:31.418 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-16 00:00:00
# 2020-07-07 15:02:41.446 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-17 00:00:00
# 2020-07-07 15:02:58.635 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-18 00:00:00
# 2020-07-07 15:03:16.028 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-19 00:00:00
# 2020-07-07 15:03:22.744 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-20 00:00:00
# 2020-07-07 15:03:36.359 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-21 00:00:00
# 2020-07-07 15:03:46.609 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-22 00:00:00
# 2020-07-07 15:03:56.965 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-23 00:00:00
# 2020-07-07 15:04:07.102 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-24 00:00:00
# 2020-07-07 15:04:13.908 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-25 00:00:00
# 2020-07-07 15:04:31.308 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-26 00:00:00
# 2020-07-07 15:04:44.930 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-27 00:00:00
# 2020-07-07 15:04:55.118 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-28 00:00:00
# 2020-07-07 15:05:05.386 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-29 00:00:00
# 2020-07-07 15:05:21.866 | DEBUG    | vivarium.framework.engine:step:140 - 2011-04-30 00:00:00
# 2020-07-07 15:05:41.457 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-01 00:00:00
# 2020-07-07 15:05:51.023 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-02 00:00:00
# 2020-07-07 15:06:07.519 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-03 00:00:00
# 2020-07-07 15:06:17.030 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-04 00:00:00
# 2020-07-07 15:06:26.748 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-05 00:00:00
# 2020-07-07 15:06:36.631 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-06 00:00:00
# 2020-07-07 15:06:53.060 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-07 00:00:00
# 2020-07-07 15:07:02.892 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-08 00:00:00
# 2020-07-07 15:07:19.154 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-09 00:00:00
# 2020-07-07 15:07:32.244 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-10 00:00:00
# 2020-07-07 15:07:45.251 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-11 00:00:00
# 2020-07-07 15:07:54.967 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-12 00:00:00
# 2020-07-07 15:08:11.381 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-13 00:00:00
# 2020-07-07 15:08:20.870 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-14 00:00:00
# 2020-07-07 15:08:30.714 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-15 00:00:00
# 2020-07-07 15:08:40.367 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-16 00:00:00
# 2020-07-07 15:08:53.221 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-17 00:00:00
# 2020-07-07 15:09:09.732 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-18 00:00:00
# 2020-07-07 15:09:22.809 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-19 00:00:00
# 2020-07-07 15:09:35.750 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-20 00:00:00
# 2020-07-07 15:09:48.756 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-21 00:00:00
# 2020-07-07 15:09:58.454 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-22 00:00:00
# 2020-07-07 15:10:08.310 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-23 00:00:00
# 2020-07-07 15:10:21.453 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-24 00:00:00
# 2020-07-07 15:10:47.765 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-25 00:00:00
# 2020-07-07 15:11:00.911 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-26 00:00:00
# 2020-07-07 15:11:14.055 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-27 00:00:00
# 2020-07-07 15:11:27.172 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-28 00:00:00
# 2020-07-07 15:11:36.848 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-29 00:00:00
# 2020-07-07 15:11:49.981 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-30 00:00:00
# 2020-07-07 15:12:03.215 | DEBUG    | vivarium.framework.engine:step:140 - 2011-05-31 00:00:00
# 2020-07-07 15:12:16.322 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-01 00:00:00
# 2020-07-07 15:12:26.032 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-02 00:00:00
# 2020-07-07 15:12:39.279 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-03 00:00:00
# 2020-07-07 15:12:48.939 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-04 00:00:00
# 2020-07-07 15:12:58.676 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-05 00:00:00
# 2020-07-07 15:13:18.558 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-06 00:00:00
# 2020-07-07 15:13:35.000 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-07 00:00:00
# 2020-07-07 15:13:48.112 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-08 00:00:00
# 2020-07-07 15:13:57.663 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-09 00:00:00
# 2020-07-07 15:14:20.957 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-10 00:00:00
# 2020-07-07 15:14:34.008 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-11 00:00:00
# 2020-07-07 15:14:43.924 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-12 00:00:00
# 2020-07-07 15:15:03.870 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-13 00:00:00
# 2020-07-07 15:15:16.870 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-14 00:00:00
# 2020-07-07 15:15:30.107 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-15 00:00:00
# 2020-07-07 15:15:43.205 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-16 00:00:00
# 2020-07-07 15:15:56.225 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-17 00:00:00
# 2020-07-07 15:16:05.988 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-18 00:00:00
# 2020-07-07 15:16:22.414 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-19 00:00:00
# 2020-07-07 15:16:35.503 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-20 00:00:00
# 2020-07-07 15:16:45.254 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-21 00:00:00
# 2020-07-07 15:16:54.988 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-22 00:00:00
# 2020-07-07 15:17:11.342 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-23 00:00:00
# 2020-07-07 15:17:21.059 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-24 00:00:00
# 2020-07-07 15:17:38.749 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-25 00:00:00
# 2020-07-07 15:17:49.886 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-26 00:00:00
# 2020-07-07 15:18:15.277 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-27 00:00:00
# 2020-07-07 15:18:25.901 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-28 00:00:00
# 2020-07-07 15:18:46.948 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-29 00:00:00
# 2020-07-07 15:18:57.580 | DEBUG    | vivarium.framework.engine:step:140 - 2011-06-30 00:00:00
# 2020-07-07 15:19:08.212 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-01 00:00:00
# 2020-07-07 15:19:15.099 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-02 00:00:00
# 2020-07-07 15:19:25.779 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-03 00:00:00
# 2020-07-07 15:19:39.605 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-04 00:00:00
# 2020-07-07 15:19:53.152 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-05 00:00:00
# 2020-07-07 15:20:06.313 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-06 00:00:00
# 2020-07-07 15:20:19.350 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-07 00:00:00
# 2020-07-07 15:20:42.760 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-08 00:00:00
# 2020-07-07 15:21:02.754 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-09 00:00:00
# 2020-07-07 15:21:16.023 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-10 00:00:00
# 2020-07-07 15:21:25.782 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-11 00:00:00
# 2020-07-07 15:21:38.971 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-12 00:00:00
# 2020-07-07 15:21:55.538 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-13 00:00:00
# 2020-07-07 15:22:08.727 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-14 00:00:00
# 2020-07-07 15:22:21.850 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-15 00:00:00
# 2020-07-07 15:22:38.465 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-16 00:00:00
# 2020-07-07 15:22:51.783 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-17 00:00:00
# 2020-07-07 15:23:08.275 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-18 00:00:00
# 2020-07-07 15:23:28.516 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-19 00:00:00
# 2020-07-07 15:23:42.487 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-20 00:00:00
# 2020-07-07 15:24:06.556 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-21 00:00:00
# 2020-07-07 15:24:26.618 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-22 00:00:00
# 2020-07-07 15:24:40.253 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-23 00:00:00
# 2020-07-07 15:24:50.508 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-24 00:00:00
# 2020-07-07 15:25:07.140 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-25 00:00:00
# 2020-07-07 15:25:24.524 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-26 00:00:00
# 2020-07-07 15:25:44.742 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-27 00:00:00
# 2020-07-07 15:26:02.164 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-28 00:00:00
# 2020-07-07 15:26:16.683 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-29 00:00:00
# 2020-07-07 15:26:26.885 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-30 00:00:00
# 2020-07-07 15:26:36.897 | DEBUG    | vivarium.framework.engine:step:140 - 2011-07-31 00:00:00
# 2020-07-07 15:26:50.403 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-01 00:00:00
# 2020-07-07 15:27:03.808 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-02 00:00:00
# 2020-07-07 15:27:20.514 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-03 00:00:00
# 2020-07-07 15:27:30.393 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-04 00:00:00
# 2020-07-07 15:27:40.556 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-05 00:00:00
# 2020-07-07 15:27:50.499 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-06 00:00:00
# 2020-07-07 15:28:07.282 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-07 00:00:00
# 2020-07-07 15:28:17.233 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-08 00:00:00
# 2020-07-07 15:28:30.333 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-09 00:00:00
# 2020-07-07 15:28:40.418 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-10 00:00:00
# 2020-07-07 15:28:53.456 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-11 00:00:00
# 2020-07-07 15:29:03.667 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-12 00:00:00
# 2020-07-07 15:29:13.614 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-13 00:00:00
# 2020-07-07 15:29:33.371 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-14 00:00:00
# 2020-07-07 15:29:50.217 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-15 00:00:00
# 2020-07-07 15:30:00.166 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-16 00:00:00
# 2020-07-07 15:30:13.787 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-17 00:00:00
# 2020-07-07 15:30:23.916 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-18 00:00:00
# 2020-07-07 15:30:37.289 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-19 00:00:00
# 2020-07-07 15:30:47.526 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-20 00:00:00
# 2020-07-07 15:30:57.133 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-21 00:00:00
# 2020-07-07 15:31:07.178 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-22 00:00:00
# 2020-07-07 15:31:23.824 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-23 00:00:00
# 2020-07-07 15:31:33.544 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-24 00:00:00
# 2020-07-07 15:31:47.456 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-25 00:00:00
# 2020-07-07 15:32:00.927 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-26 00:00:00
# 2020-07-07 15:32:17.893 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-27 00:00:00
# 2020-07-07 15:32:31.457 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-28 00:00:00
# 2020-07-07 15:32:42.361 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-29 00:00:00
# 2020-07-07 15:32:52.557 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-30 00:00:00
# 2020-07-07 15:33:09.458 | DEBUG    | vivarium.framework.engine:step:140 - 2011-08-31 00:00:00
# 2020-07-07 15:33:23.190 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-01 00:00:00
# 2020-07-07 15:33:33.225 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-02 00:00:00
# 2020-07-07 15:33:43.564 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-03 00:00:00
# 2020-07-07 15:34:03.918 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-04 00:00:00
# 2020-07-07 15:34:20.915 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-05 00:00:00
# 2020-07-07 15:34:37.691 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-06 00:00:00
# 2020-07-07 15:34:51.031 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-07 00:00:00
# 2020-07-07 15:35:00.942 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-08 00:00:00
# 2020-07-07 15:35:10.875 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-09 00:00:00
# 2020-07-07 15:35:20.834 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-10 00:00:00
# 2020-07-07 15:35:34.051 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-11 00:00:00
# 2020-07-07 15:35:43.999 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-12 00:00:00
# 2020-07-07 15:36:04.415 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-13 00:00:00
# 2020-07-07 15:36:14.645 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-14 00:00:00
# 2020-07-07 15:36:28.996 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-15 00:00:00
# 2020-07-07 15:36:42.987 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-16 00:00:00
# 2020-07-07 15:36:56.741 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-17 00:00:00
# 2020-07-07 15:37:10.347 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-18 00:00:00
# 2020-07-07 15:37:20.670 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-19 00:00:00
# 2020-07-07 15:37:30.841 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-20 00:00:00
# 2020-07-07 15:37:44.585 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-21 00:00:00
# 2020-07-07 15:37:54.740 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-22 00:00:00
# 2020-07-07 15:38:04.796 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-23 00:00:00
# 2020-07-07 15:38:18.219 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-24 00:00:00
# 2020-07-07 15:38:31.735 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-25 00:00:00
# 2020-07-07 15:38:52.508 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-26 00:00:00
# 2020-07-07 15:39:10.100 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-27 00:00:00
# 2020-07-07 15:39:23.830 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-28 00:00:00
# 2020-07-07 15:39:41.331 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-29 00:00:00
# 2020-07-07 15:39:51.549 | DEBUG    | vivarium.framework.engine:step:140 - 2011-09-30 00:00:00
# 2020-07-07 15:40:01.952 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-01 00:00:00
# 2020-07-07 15:40:15.894 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-02 00:00:00
# 2020-07-07 15:40:29.716 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-03 00:00:00
# 2020-07-07 15:40:43.618 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-04 00:00:00
# 2020-07-07 15:40:54.061 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-05 00:00:00
# 2020-07-07 15:41:10.786 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-06 00:00:00
# 2020-07-07 15:41:24.040 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-07 00:00:00
# 2020-07-07 15:41:33.855 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-08 00:00:00
# 2020-07-07 15:41:44.386 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-09 00:00:00
# 2020-07-07 15:42:01.654 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-10 00:00:00
# 2020-07-07 15:42:19.022 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-11 00:00:00
# 2020-07-07 15:42:32.975 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-12 00:00:00
# 2020-07-07 15:42:43.680 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-13 00:00:00
# 2020-07-07 15:42:54.000 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-14 00:00:00
# 2020-07-07 15:43:14.785 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-15 00:00:00
# 2020-07-07 15:43:25.399 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-16 00:00:00
# 2020-07-07 15:43:45.507 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-17 00:00:00
# 2020-07-07 15:44:02.992 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-18 00:00:00
# 2020-07-07 15:44:13.410 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-19 00:00:00
# 2020-07-07 15:44:20.314 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-20 00:00:00
# 2020-07-07 15:44:30.415 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-21 00:00:00
# 2020-07-07 15:44:43.842 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-22 00:00:00
# 2020-07-07 15:44:53.934 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-23 00:00:00
# 2020-07-07 15:45:07.813 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-24 00:00:00
# 2020-07-07 15:45:21.616 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-25 00:00:00
# 2020-07-07 15:45:32.384 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-26 00:00:00
# 2020-07-07 15:45:42.629 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-27 00:00:00
# 2020-07-07 15:45:52.717 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-28 00:00:00
# 2020-07-07 15:46:14.321 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-29 00:00:00
# 2020-07-07 15:46:21.338 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-30 00:00:00
# 2020-07-07 15:46:35.209 | DEBUG    | vivarium.framework.engine:step:140 - 2011-10-31 00:00:00
# 2020-07-07 15:46:48.789 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-01 00:00:00
# 2020-07-07 15:46:59.105 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-02 00:00:00
# 2020-07-07 15:47:13.007 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-03 00:00:00
# 2020-07-07 15:47:30.397 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-04 00:00:00
# 2020-07-07 15:47:40.859 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-05 00:00:00
# 2020-07-07 15:47:52.094 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-06 00:00:00
# 2020-07-07 15:48:16.387 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-07 00:00:00
# 2020-07-07 15:48:37.126 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-08 00:00:00
# 2020-07-07 15:48:50.666 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-09 00:00:00
# 2020-07-07 15:49:07.670 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-10 00:00:00
# 2020-07-07 15:49:17.923 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-11 00:00:00
# 2020-07-07 15:49:34.961 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-12 00:00:00
# 2020-07-07 15:49:45.041 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-13 00:00:00
# 2020-07-07 15:50:08.913 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-14 00:00:00
# 2020-07-07 15:50:22.497 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-15 00:00:00
# 2020-07-07 15:50:36.114 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-16 00:00:00
# 2020-07-07 15:50:53.307 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-17 00:00:00
# 2020-07-07 15:51:03.830 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-18 00:00:00
# 2020-07-07 15:51:17.399 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-19 00:00:00
# 2020-07-07 15:51:31.231 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-20 00:00:00
# 2020-07-07 15:51:44.713 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-21 00:00:00
# 2020-07-07 15:51:58.694 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-22 00:00:00
# 2020-07-07 15:52:11.988 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-23 00:00:00
# 2020-07-07 15:52:25.847 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-24 00:00:00
# 2020-07-07 15:52:39.630 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-25 00:00:00
# 2020-07-07 15:52:53.562 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-26 00:00:00
# 2020-07-07 15:53:03.502 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-27 00:00:00
# 2020-07-07 15:53:20.293 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-28 00:00:00
# 2020-07-07 15:53:40.517 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-29 00:00:00
# 2020-07-07 15:53:57.234 | DEBUG    | vivarium.framework.engine:step:140 - 2011-11-30 00:00:00
# 2020-07-07 15:54:07.152 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-01 00:00:00
# 2020-07-07 15:54:20.864 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-02 00:00:00
# 2020-07-07 15:54:34.587 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-03 00:00:00
# 2020-07-07 15:54:47.999 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-04 00:00:00
# 2020-07-07 15:55:01.540 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-05 00:00:00
# 2020-07-07 15:55:12.026 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-06 00:00:00
# 2020-07-07 15:55:36.238 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-07 00:00:00
# 2020-07-07 15:55:50.318 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-08 00:00:00
# 2020-07-07 15:56:01.575 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-09 00:00:00
# 2020-07-07 15:56:12.193 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-10 00:00:00
# 2020-07-07 15:56:29.399 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-11 00:00:00
# 2020-07-07 15:56:43.391 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-12 00:00:00
# 2020-07-07 15:56:53.363 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-13 00:00:00
# 2020-07-07 15:57:10.756 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-14 00:00:00
# 2020-07-07 15:57:32.292 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-15 00:00:00
# 2020-07-07 15:58:00.322 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-16 00:00:00
# 2020-07-07 15:58:13.779 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-17 00:00:00
# 2020-07-07 15:58:23.887 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-18 00:00:00
# 2020-07-07 15:58:41.372 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-19 00:00:00
# 2020-07-07 15:59:02.532 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-20 00:00:00
# 2020-07-07 15:59:13.165 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-21 00:00:00
# 2020-07-07 15:59:23.962 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-22 00:00:00
# 2020-07-07 15:59:37.944 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-23 00:00:00
# 2020-07-07 15:59:48.333 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-24 00:00:00
# 2020-07-07 16:00:06.206 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-25 00:00:00
# 2020-07-07 16:00:21.813 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-26 00:00:00
# 2020-07-07 16:00:35.960 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-27 00:00:00
# 2020-07-07 16:00:50.092 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-28 00:00:00
# 2020-07-07 16:01:07.874 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-29 00:00:00
# 2020-07-07 16:01:22.313 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-30 00:00:00
# 2020-07-07 16:01:32.859 | DEBUG    | vivarium.framework.engine:step:140 - 2011-12-31 00:00:00
# 2020-07-07 16:01:43.347 | DEBUG    | vivarium.framework.engine:step:140 - 2012-01-01 00:00:00
# 2020-07-07 16:01:53.807 | DEBUG    | vivarium.framework.engine:step:140 - 2012-01-02 00:00:00
# 2020-07-07 16:02:04.162 | DEBUG    | vivarium.framework.engine:step:140 - 2012-01-03 00:00:00
# 2020-07-07 16:02:18.097 | DEBUG    | vivarium.framework.engine:step:140 - 2012-01-04 00:00:00
# 2020-07-07 16:02:31.714 | DEBUG    | vivarium.framework.engine:step:140 - 2012-01-05 00:00:00
# 2020-07-07 16:02:42.278 | DEBUG    | vivarium.framework.engine:step:140 - 2012-01-06 00:00:00
# 2020-07-07 16:02:56.133 | DEBUG    | vivarium.framework.engine:step:140 - 2012-01-07 00:00:00
# 2020-07-07 16:03:09.909 | DEBUG    | vivarium.framework.engine:step:140 - 2012-01-08 00:00:00
# 2020-07-07 16:03:27.175 | DEBUG    | vivarium.framework.engine:step:140 - 2012-01-09 00:00:00
# 2020-07-07 16:03:41.350 | DEBUG    | vivarium.framework.engine:step:140 - 2012-01-10 00:00:00

# %%
pop = simulation.get_population()

print(f"Total time: {sim_end - sim_start}")
print (f'#alive: {len(pop[pop["alive"]=="alive"])}')
print (f'#dead: {len(pop[pop["alive"]!="alive"])}')
print (f'#new borns: {len(pop[pop["parent_id"]!=-1])}')
# Out:
# Total time: 5292.407145023346
# #alive: 528098
# #dead: 4293
# #new borns: 9970

# %% [markdown]
# ## Plot results

# %%
#min_time = pop["entrance_time"].min().strftime("%Y-%m-%d")
min_time = "2011-01-01"
max_time = datetime.datetime.strptime("2012-12-31", "%Y-%m-%d")

print("min_time:", min_time)
print("max_time:", max_time)
# Out:
# min_time: 2011-01-01
# max_time: 2012-12-31 00:00:00

# %%
# --- input
# intervals for plotting (in days)
interval_in_days = 10
# list of ethnicities
sel_ethnicity = ["WBI", "WHO"]

# Population (total, for selected ethnicities, gender)
total_population = len(pop)
total_population_ETH = len(pop[pop["ethnicity"].isin(sel_ethnicity)])
total_population_male = len(pop[pop["sex"] == 1])
total_population_female = len(pop[pop["sex"] == 2])

time_axis = []
population_axis = []
population_ETH_axis = []
population_M_axis = []
population_F_axis = []

curr_time = datetime.datetime.strptime(min_time, "%Y-%m-%d")
while curr_time <= max_time:
    time_axis.append(curr_time)
    
    # dead population until current time (changes in the while loop)
    pop_dead = pop[pop["exit_time"] <= curr_time.strftime("%Y-%m-%d")]
    
    num_dead_population = total_population - len(pop_dead)
    population_axis.append(num_dead_population)
    
    num_dead_population_eth = total_population_ETH - len(pop_dead[pop_dead["ethnicity"].isin(sel_ethnicity)])
    population_ETH_axis.append(num_dead_population_eth)
    
    num_dead_male = total_population_male - len(pop_dead[pop_dead["sex"] == 1])
    population_M_axis.append(num_dead_male)
    
    num_dead_female = total_population_female - len(pop_dead[pop_dead["sex"] == 2])
    population_F_axis.append(num_dead_female)
    
    # go to next time, according to the selected interval_in_days
    curr_time = datetime.datetime.strptime(curr_time.strftime("%Y-%m-%d"), "%Y-%m-%d")
    curr_time += datetime.timedelta(days=interval_in_days)

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
# Population (total)
plt.figure(figsize=(15, 10))
plt.plot(time_axis, population_axis, 
         c='k', lw=4, marker="o")
plt.xlabel("Time", size=32)
plt.ylabel("Population", size=32)
plt.xticks(size=24, rotation=90)
plt.yticks(size=24)
plt.grid()
plt.show()

# %%
# Population (gender)
plt.figure(figsize=(15, 10))
plt.plot(time_axis, population_M_axis, 
         c='k', lw=4, marker="o", 
         label="Male"
        )
plt.plot(time_axis, population_F_axis, 
         c='r', lw=4, marker="o",
         label="Female"
        )
plt.xlabel("Time", size=32)
plt.ylabel("Population", size=32)
plt.xticks(size=24, rotation=90)
plt.yticks(size=24)
plt.grid()
plt.legend(fontsize=24)
plt.show()

# %%
# Population (ethnicity)
plt.figure(figsize=(15, 10))
plt.plot(time_axis, population_ETH_axis, 
         c='k', lw=4, marker="o", 
         label=sel_ethnicity
        )
plt.xlabel("Time", size=32)
plt.ylabel("Population", size=32)
plt.xticks(size=24, rotation=90)
plt.yticks(size=24)
plt.grid()
plt.legend(fontsize=24)
plt.show()

# %% [markdown]
# ## Histograms

# %%
# only dead population
pop_dead = pop[pop["alive"] != "alive"]

# %%
series2plot = pop_dead['ethnicity'].value_counts() / len(pop_dead["ethnicity"]) * 100.
indx = range(len(series2plot))

plt.figure(figsize=(15, 10))
plt.bar(indx, series2plot, color='k')

plt.xticks(indx, series2plot.index, size=24)
plt.yticks(size=24)
plt.xlabel("Ethnicity", size=32)
plt.ylabel("%", size=32)

plt.grid()
#plt.legend(fontsize=24)
plt.show()

# %%
series2plot = pop_dead['sex'].value_counts() / len(pop_dead["sex"]) * 100.
indx = range(len(series2plot))

plt.figure(figsize=(15, 10))
plt.bar(indx, series2plot, color='k')

plt.xticks(indx, series2plot.index, size=24)
plt.yticks(size=24)
plt.xlabel("Gender", size=32)
plt.ylabel("%", size=32)

plt.grid()
#plt.legend(fontsize=24)
plt.show()

# %%
plt.figure(figsize=(15, 10))

pop_dead["exit_time"].hist(bins=20, 
                           rwidth=0.9, 
                           color='k',
                           align='left'
                          )
plt.xlabel("Time", size=32)
plt.ylabel("Mortality", size=32)
plt.xticks(size=24, rotation=90)
plt.yticks(size=24)
#plt.legend(fontsize=24)
plt.show()

# %%
plt.figure(figsize=(15, 10))

pop_dead["age"].hist(bins=range(0, 100, 5), 
                     rwidth=0.9, 
                     color='k',
                     align='left'
                    )
plt.xlabel("Age", size=32)
plt.ylabel("Mortality", size=32)
plt.xticks(size=24)
plt.yticks(size=24)
#plt.legend(fontsize=24)
plt.show()

# %%
plt.figure(figsize=(15, 10))

pop_dead["location"].hist(bins=100, 
                          rwidth=0.9, 
                          color='k',
                          align="left"
                         )
plt.xlabel("Location", size=32)
plt.ylabel("Mortality", size=32)
plt.xticks(size=24)
plt.yticks(size=24)
#plt.legend(fontsize=24)
plt.show()

# %% [markdown]
# # Fetility

# %%
pop_births = pop[pop['parent_id']!= -1]

# %% [markdown]
# ## Ethnicity of new births

# %%
series2plot_births = pop_births['ethnicity'].value_counts() / len(pop_births["ethnicity"]) * 100.
indx = range(len(series2plot_births))

plt.figure(figsize=(15, 10))
plt.bar(indx, series2plot_births, color='k')

plt.xticks(indx, series2plot_births.index, size=24)
plt.yticks(size=24)
plt.xlabel("Ethnicity", size=32)
plt.ylabel("%", size=32)

plt.grid()
#plt.legend(fontsize=24)
plt.show()

# %%
plt.figure(figsize=(15, 10))

pop_births["entrance_time"].hist(bins=20, 
                           rwidth=0.9, 
                           color='k',
                           align='left'
                          )
plt.xlabel("Time", size=32)
plt.ylabel("Born babies", size=32)
plt.xticks(size=24, rotation=90)
plt.yticks(size=24)
#plt.legend(fontsize=24)
plt.show()

# %% [markdown]
# ## Age of mothers

# %%
plt.figure(figsize=(15, 10))

pop.iloc[pop_births["parent_id"]]["age"].hist(bins=range(0, 100, 5), 
                     rwidth=0.9, 
                     color='k',
                     align='left'
                    )
plt.xlabel("Age", size=32)
plt.ylabel("Frequency", size=32)
plt.xticks(size=24)
plt.yticks(size=24)

#plt.legend(fontsize=24)
plt.show()
